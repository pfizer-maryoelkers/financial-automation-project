# %% [markdown]
# ## EDA - Exploring Forecast and C-Ties Excel Files Using Openpyxl
#
# This notebook will demonstrate extracting rows and columns from both forecast files and c-ties files for transformation

# %%
import openpyxl as px
import streamlit as st
import json

# %%
#TODO: explore excel files in root directory

data = {
    "PO": None,
    "January": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "February": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "March": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "April": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "May": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "June": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "July": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "August": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "September": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "October": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "November": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    },
    "December": {
        "Accrual Reversal": None,
        "Forecast": None,
        "Accrual": None,
        "Actual": None
    }
    
}
